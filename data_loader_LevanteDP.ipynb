# %%
import anemiaLevanteDP as a

# %%
# Load the data
directory = '/home/jovyan/work/Data/LevanteDP/Registro_levante'
file_prefix = 'LevanteDP'
file_extension = '.xls'
dfs = a.load_and_merge_files(directory, file_prefix, file_extension, verbose=True)
# Out:
# Added 429 rows from LevanteDP(5).xls to Pacientes
# Added 326 rows from LevanteDP(5).xls to Peritonitis
# Added 199 rows from LevanteDP(5).xls to Ingresos
# Added 102 rows from LevanteDP(5).xls to Excl.Temp.
# Added 47 rows from LevanteDP(5).xls to Catéter
# Added 756 rows from LevanteDP(5).xls to Cinética P.
# Added 177 rows from LevanteDP(5).xls to M.O.M
# Added 1484 rows from LevanteDP(5).xls to Analíticas
# Added 0 rows from LevanteDP(5).xls to Anemia
# Added 197 rows from LevanteDP(4).xls to Pacientes
# Added 100 rows from LevanteDP(4).xls to Peritonitis
# Added 89 rows from LevanteDP(4).xls to Ingresos
# Added 50 rows from LevanteDP(4).xls to Excl.Temp.
# Added 6 rows from LevanteDP(4).xls to Catéter
# Added 260 rows from LevanteDP(4).xls to Cinética P.
# Added 120 rows from LevanteDP(4).xls to M.O.M
# Added 728 rows from LevanteDP(4).xls to Analíticas
# Added 0 rows from LevanteDP(4).xls to Anemia
# Added 240 rows from LevanteDP(12).xls to Pacientes
# ...
